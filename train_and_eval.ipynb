# %% [markdown]
# # Sensor-to-LLM Training and Evaluation
# This notebook runs the training pipeline at seed 90:
# 1. Train the direct sensor classifier (no LLM)
# 2. Train the context embedding model
# 3. Evaluate the sensor-dependence check using weights from the context embedding model

# %%
# !python src/train_direct.py --seed 90

# %%
# !python src/train_context.py --seed 90

# %%
# !python src/sensor_dependence_check.py --seed 90
